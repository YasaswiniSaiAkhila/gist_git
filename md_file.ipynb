# %% [markdown]
# # title
# ***
# 1.hi
# ***

# %% [markdown]
# ***le***

# %% [markdown]
# **HI**

# %% [markdown]
# *HI*

# %% [markdown]
# - [GOOGLE](https://www.google.com)

# %% [markdown]
# - game
#      1. hi
#      2. hello
#         - who r you?

# %% [markdown]
# - ![](data:image/jpeg;base64,...)

# %% [markdown]
# # hi
# can you identify which is highletd
# ```this is highleted```
# this is not
# `yes`

# %% [markdown]
# - ![](data:image/jpeg;base64,...)
